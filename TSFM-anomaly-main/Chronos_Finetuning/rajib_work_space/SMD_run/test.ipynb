# %%
import glob
import pandas as pd
import pickle

# %%
path = "/home/rajib/Sir_git_TSAD/TSFM-anomaly/Chronos_Finetuning/rajib_work_space/SMD_run/test_*.pkl"

# %%
file = glob.glob(path)

# %%
meta, test = file

# %%
with open (meta, 'rb') as file:
    data_meta = pickle.load(file)
with open (test, 'rb') as file:
    data_test = pickle.load(file)

# %%
print(data_meta['SMD_machine-2-1_test.csv'])
# Out:
# {'length': 12706, 'labels': array([0, 0, 0, ..., 0, 0, 0], shape=(12706,), dtype=int32), 'n_features': 38, 'context_length': 512}

# %%
print((data_test[0]['target'][0])[-1])
print((data_test[1]['target'][0])[0])
# Out:
# 0.141414
# 0.141414

# %%
for _, data in enumerate(data_test):
    print(data["series_id"])
    print(data["future_start"])
    print(data["future_end"])
    print(data["series_length"])
# Out:
# SMD_machine-2-1_test.csv
# 512
# 576
# 12706
# SMD_machine-2-1_test.csv
# 576
# 640
# 12706
# SMD_machine-2-1_test.csv
# 640
# 704
# 12706
# SMD_machine-2-1_test.csv
# 704
# 768
# 12706
# SMD_machine-2-1_test.csv
# 768
# 832
# 12706
# SMD_machine-2-1_test.csv
# 832
# 896
# 12706
# SMD_machine-2-1_test.csv
# 896
# 960
# 12706
# SMD_machine-2-1_test.csv
# 960
# 1024
# 12706
# SMD_machine-2-1_test.csv
# 1024
# 1088
# 12706
# SMD_machine-2-1_test.csv
# 1088
# 1152
# 12706
# SMD_machine-2-1_test.csv
# 1152
# 1216
# 12706
# SMD_machine-2-1_test.csv
# 1216
# 1280
# 12706
# SMD_machine-2-1_test.csv
# 1280
# 1344
# 12706
# SMD_machine-2-1_test.csv
# 1344
# 1408
# 12706
# SMD_machine-2-1_test.csv
# 1408
# 1472
# 12706
# SMD_machine-2-1_test.csv
# 1472
# 1536
# 12706
# SMD_machine-2-1_test.csv
# 1536
# 1600
# 12706
# SMD_machine-2-1_test.csv
# 1600
# 1664
# 12706
# SMD_machine-2-1_test.csv
# 1664
# 1728
# 12706
# SMD_machine-2-1_test.csv
# 1728
# 1792
# 12706
# SMD_machine-2-1_test.csv
# 1792
# ...

# %%
print(data_test[0]["series_id"])
print(data_test[0]["future_start"])
print(data_test[0]["future_end"])
print(data_test[0]["series_length"])
# Out:
# SMD_machine-2-1_test.csv
# 512
# 576
# 12706

# %%
print(data_test[1]["series_id"])
print(data_test[1]["future_start"])
print(data_test[1]["future_end"])
print(data_test[1]["series_length"])
# Out:
# SMD_machine-2-1_test.csv
# 576
# 640
# 12706
