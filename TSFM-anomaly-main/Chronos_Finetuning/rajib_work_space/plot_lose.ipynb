# %% [markdown]
# # Chronos-2 Single-Stage Anomaly Fine-Tuning — Loss Curves
#
# Loads `trainer_state.json` from the single-stage checkpoint directory and plots the
# **normal-future loss** and **anomaly-future loss** separately.
#
# Both are the model's RAW prediction error (positive):
# - **Normal loss** is minimized → should go **down**.
# - **Anomaly loss** is maximized (gradient ascent) → should go **up** (until it hits the loss ceiling).
#
# > **Note:** these separate curves require the per-type logging added to
# > `finetune_anomaly_simple.py`. Runs started before that change only have the
# > combined `loss`/`eval_loss` and will show empty normal/anomaly curves.

# %%
import json
import os

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

OUTPUT_DIR = "/home/rajib/Sir_git_TSAD/TSFM-anomaly/Chronos_Finetuning/rajib_work_space/chronos2-single-stage_NS1000_V5"

# %%
def load_log_history(output_dir):
    """
    Find and load trainer_state.json from output_dir.

    Several trainer_state.json files can exist: the one written at the root of
    output_dir at the end of training (the COMPLETE history), plus a partial
    copy inside every checkpoint-NNNN/ subdir. We load whichever has the
    largest final step so the curves cover the whole run — otherwise the plot
    would stop at the last saved checkpoint (e.g. step 3400 instead of 5000).
    """
    candidates = [os.path.join(output_dir, "trainer_state.json")]
    if os.path.isdir(output_dir):
        for name in sorted(os.listdir(output_dir)):
            if name.startswith("checkpoint-") or name == "finetuned-ckpt":
                candidates.append(os.path.join(output_dir, name, "trainer_state.json"))

    best_history, best_path, best_last_step = None, None, -1
    for path in candidates:
        if not os.path.exists(path):
            continue
        with open(path) as f:
            history = json.load(f)["log_history"]
        last_step = max((e["step"] for e in history), default=-1)
        if last_step > best_last_step:
            best_history, best_path, best_last_step = history, path, last_step

    if best_history is None:
        raise FileNotFoundError(f"No trainer_state.json found under {output_dir}")

    print(f"Loaded {len(best_history)} entries (up to step {best_last_step}) from {best_path}")
    return best_history


def series(log_history, key):
    """Return (steps, values) for every entry that contains `key`."""
    steps, values = [], []
    for entry in log_history:
        if key in entry:
            steps.append(entry["step"])
            values.append(entry[key])
    return steps, values

# %%
history = load_log_history(OUTPUT_DIR)

# Train curves (per-type) + eval curves (per-type), all RAW positive losses
n_tr_s,  n_tr_l  = series(history, "normal_loss")
a_tr_s,  a_tr_l  = series(history, "anomaly_loss")
n_ev_s,  n_ev_l  = series(history, "eval_val_normal_loss")
a_ev_s,  a_ev_l  = series(history, "eval_val_anomaly_loss")

# Combined (total) loss
c_tr_s,  c_tr_l  = series(history, "loss")
c_ev_s,  c_ev_l  = series(history, "eval_val_loss")

print(f"normal_loss points: {len(n_tr_l)} | anomaly_loss points: {len(a_tr_l)}")
if not n_tr_l and not a_tr_l:
    print("No per-type losses found — this run predates per-type logging. "
          "Showing combined loss only.")
# Out:
# Loaded 72 entries (up to step 1800) from /home/rajib/Sir_git_TSAD/TSFM-anomaly/Chronos_Finetuning/rajib_work_space/chronos2-single-stage_NS1000_V5/trainer_state.json
# normal_loss points: 36 | anomaly_loss points: 36

# %%
def plot_curve(ax, tr_s, tr_l, ev_s, ev_l, title, color):
    ax.plot(tr_s, tr_l, color=color, linewidth=1.2, label="Train", alpha=0.85)
    if ev_s:
        ax.plot(ev_s, ev_l, color=color, linewidth=1.8, linestyle="--",
                marker="o", markersize=3, label="Val", alpha=0.95)
    ax.set_title(title, fontsize=11, fontweight="bold")
    ax.set_xlabel("Step")
    ax.set_ylabel("Loss")
    ax.legend(fontsize=9)
    ax.grid(True, linestyle=":", alpha=0.5)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)


# ── Breakdown: three separate panels ────────────────────────────────────────
fig = plt.figure(figsize=(18, 5))
gs  = gridspec.GridSpec(1, 3, wspace=0.30)

ax1 = fig.add_subplot(gs[0])
plot_curve(ax1, n_tr_s, n_tr_l, n_ev_s, n_ev_l,
           "1. Normal future loss\n(minimize -> DOWN)", color="#1f77b4")

ax2 = fig.add_subplot(gs[1])
plot_curve(ax2, a_tr_s, a_tr_l, a_ev_s, a_ev_l,
           "2. Anomaly future loss\n(maximize -> UP)", color="#d62728")

ax3 = fig.add_subplot(gs[2])
plot_curve(ax3, c_tr_s, c_tr_l, c_ev_s, c_ev_l,
           "3. Overall loss\n(combined objective, signed)", color="#2ca02c")

fig.suptitle("Chronos-2 Single-Stage Anomaly Fine-Tuning - Loss Breakdown",
             fontsize=13, y=1.03)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, "loss_curves.png"), dpi=150, bbox_inches="tight")
plt.show()


# fig2, axL = plt.subplots(figsize=(10, 5))
axR = axL.twinx()

lines = []
if n_tr_s: lines += axL.plot(n_tr_s, n_tr_l, color="#1f77b4", linewidth=1.5, label="Normal future (left)")
if c_tr_s: lines += axL.plot(c_tr_s, c_tr_l, color="#2ca02c", linewidth=1.5, label="Overall objective (left)")
if a_tr_s: lines += axR.plot(a_tr_s, a_tr_l, color="#d62728", linewidth=1.5, label="Anomaly future (right)")

axL.axhline(0, color="gray", linewidth=0.8, linestyle=":")
axL.set_xlabel("Step")
axL.set_ylabel("Normal / Overall loss")
axR.set_ylabel("Anomaly loss", color="#c40f0f")
axR.tick_params(axis="y", labelcolor="#d62728")
axL.set_title("All loss curves (train) - twin axes", fontsize=12, fontweight="bold")
axL.legend(lines, [ln.get_label() for ln in lines], fontsize=9, loc="best")
axL.grid(True, linestyle=":", alpha=0.5)
axL.spines["top"].set_visible(False)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, "loss_curves_combined.png"), dpi=150, bbox_inches="tight")
plt.show()
# Out:
# /tmp/ipykernel_834974/3671648584.py:33: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 39
#      35 plt.show()
#      38 # fig2, axL = plt.subplots(figsize=(10, 5))
# ---> 39 axR = axL.twinx()
#      41 lines = []
#      42 if n_tr_s: lines += axL.plot(n_tr_s, n_tr_l, color="#1f77b4", linewidth=1.5, label="Normal future (left)")
#
# NameError: name 'axL' is not defined

# %% [markdown]
# ## Normal / Anomaly / Total loss — one panel per split (train · val · test)
#
# Each panel plots the three losses (**normal**, **anomaly**, **total**) on the same axes,
# so you can read them against each other for that split.
#
# Keys in `trainer_state.json`:
#
# | Split | Normal | Anomaly | Total |
# |-------|--------|---------|-------|
# | Train | `normal_loss` | `anomaly_loss` | `loss` |
# | Val   | `eval_val_normal_loss` | `eval_val_anomaly_loss` | `eval_val_loss` |
# | Test  | `eval_test_normal_loss` | `eval_test_anomaly_loss` | `eval_test_loss` |

# %%
# Reload history in case the run was updated, then pull every split's 3 losses.
history = load_log_history(OUTPUT_DIR)

# (normal_key, anomaly_key, total_key, panel title)
SPLITS = [
    ("normal_loss",            "anomaly_loss",            "loss",            "Training"),
    ("eval_val_normal_loss",   "eval_val_anomaly_loss",   "eval_val_loss",   "Validation"),
    ("eval_test_normal_loss",  "eval_test_anomaly_loss",  "eval_test_loss",  "Test"),
]

COLORS = {"normal": "#1f77b4", "anomaly": "#d62728", "total": "#2ca02c"}


def draw_split(ax, n_key, a_key, t_key, title):
    """Plot normal, anomaly and total loss for one split on a single axis."""
    drew = False
    for key, name, color in (
        (n_key, "Normal loss",  COLORS["normal"]),
        (a_key, "Anomaly loss", COLORS["anomaly"]),
        (t_key, "Total loss",   COLORS["total"]),
    ):
        s, v = series(history, key)
        if s:
            ax.plot(s, v, color=color, linewidth=1.6, marker="o", markersize=3,
                    label=name, alpha=0.9)
            drew = True
    if not drew:
        ax.text(0.5, 0.5, "no data", ha="center", va="center",
                transform=ax.transAxes, color="gray")
    ax.set_title(title, fontsize=12, fontweight="bold")
    ax.set_xlabel("Step")
    ax.set_ylabel("Loss")
    ax.legend(fontsize=9)
    ax.grid(True, linestyle=":", alpha=0.5)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)


fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, (n_key, a_key, t_key, title) in zip(axes, SPLITS):
    draw_split(ax, n_key, a_key, t_key, title)

fig.suptitle("Normal vs Anomaly vs Total loss  —  Train · Validation · Test",
             fontsize=13, fontweight="bold", y=1.02)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, "loss_normal_anomaly_total_by_split.png"),
            dpi=150, bbox_inches="tight")
plt.show()
# Out:
# Loaded 72 entries (up to step 1800) from /home/rajib/Sir_git_TSAD/TSFM-anomaly/Chronos_Finetuning/rajib_work_space/chronos2-single-stage_NS1000_V5/trainer_state.json
